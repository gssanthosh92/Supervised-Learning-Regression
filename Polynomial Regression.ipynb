# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston

import statsmodels.api as sm

# %%
boston = load_boston()
cols = boston.feature_names
bos = pd.DataFrame(boston.data, columns=cols)
bos['Price']=boston.target

# %%
y = bos['Price']
X = bos.drop('Price', axis=1)
#xc = sm.add_constant(X)

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures()

x = pf.fit_transform(X)

list = pf.get_feature_names(X.columns)
x = pd.DataFrame(x, columns=list)

# %%
x.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 105 columns):
# 1                float64
# CRIM             float64
# ZN               float64
# INDUS            float64
# CHAS             float64
# NOX              float64
# RM               float64
# AGE              float64
# DIS              float64
# RAD              float64
# TAX              float64
# PTRATIO          float64
# B                float64
# LSTAT            float64
# CRIM^2           float64
# CRIM ZN          float64
# CRIM INDUS       float64
# CRIM CHAS        float64
# CRIM NOX         float64
# CRIM RM          float64
# CRIM AGE         float64
# CRIM DIS         float64
# CRIM RAD         float64
# CRIM TAX         float64
# CRIM PTRATIO     float64
# CRIM B           float64
# CRIM LSTAT       float64
# ZN^2             float64
# ZN INDUS         float64
# ZN CHAS          float64
# ZN NOX           float64
# ZN RM            float64
# ZN AGE           float64
# ZN DIS           float64
# ZN RAD           float64
# ZN TAX           float64
# ZN PTRATIO       float64
# ZN B             float64
# ZN LSTAT         float64
# INDUS^2          float64
# INDUS CHAS       float64
# INDUS NOX        float64
# INDUS RM         float64
# INDUS AGE        float64
# INDUS DIS        float64
# INDUS RAD        float64
# INDUS TAX        float64
# INDUS PTRATIO    float64
# INDUS B          float64
# INDUS LSTAT      float64
# CHAS^2           float64
# CHAS NOX         float64
# CHAS RM          float64
# CHAS AGE         float64
# CHAS DIS         float64
# CHAS RAD         float64
# CHAS TAX         float64
# CHAS PTRATIO     float64
# CHAS B           float64
# CHAS LSTAT       float64
# NOX^2            float64
# NOX RM           float64
# NOX AGE          float64
# NOX DIS          float64
# NOX RAD          float64
# NOX TAX          float64
# NOX PTRATIO      float64
# NOX B            float64
# NOX LSTAT        float64
# RM^2             float64
# RM AGE           float64
# RM DIS           float64
# RM RAD           float64
# RM TAX           float64
# RM PTRATIO       float64
# RM B             float64
# RM LSTAT         float64
# AGE^2            float64
# AGE DIS          float64
# AGE RAD          float64
# AGE TAX          float64
# AGE PTRATIO      float64
# AGE B            float64
# AGE LSTAT        float64
# DIS^2            float64
# DIS RAD          float64
# DIS TAX          float64
# DIS PTRATIO      float64
# DIS B            float64
# DIS LSTAT        float64
# RAD^2            float64
# RAD TAX          float64
# RAD PTRATIO      float64
# RAD B            float64
# RAD LSTAT        float64
# TAX^2            float64
# TAX PTRATIO      float64
# TAX B            float64
# TAX LSTAT        float64
# PTRATIO^2        float64
# PTRATIO B        float64
# PTRATIO LSTAT    float64
# B^2              float64
# B LSTAT          float64
# LSTAT^2          float64
# dtypes: float64(105)
# memory usage: 415.2 KB

# %%
lin_reg = sm.OLS(y, x)
result = lin_reg.fit()

print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     51.18
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):          7.82e-180
# Time:                        14:59:46   Log-Likelihood:                -1170.5
# No. Observations:                 506   AIC:                             2549.
# Df Residuals:                     402   BIC:                             2989.
# Df Model:                         103
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# TAX PTRATIO       0.0055      0.003      2.124      0.034       0.000       0.011
# TAX B         -9.149e-05      0.000     -0.459      0.646      -0.000       0.000
# TAX LSTAT        -0.0006      0.001     -0.489      0.625      -0.003       0.002
# PTRATIO^2         0.0170      0.060      0.285      0.776      -0.100       0.135
# PTRATIO B         0.0025      0.003      0.755      0.450      -0.004       0.009
# PTRATIO LSTAT     0.0051      0.030      0.166      0.868      -0.055       0.065
# B^2           -3.647e-05   2.24e-05     -1.625      0.105   -8.06e-05    7.65e-06
# B LSTAT          -0.0005      0.000     -1.108      0.269      -0.001       0.000
# LSTAT^2           0.0131      0.005      2.647      0.008       0.003       0.023
# ==============================================================================
# Omnibus:                      138.957   Durbin-Watson:                   1.598
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              905.863
# Skew:                           1.024   Prob(JB):                    1.97e-197
# Kurtosis:                       9.227   Cond. No.                     1.11e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.91e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Backward Elimination

# %%
cols = x.columns.tolist()
pmax=1

while (len(cols)>0):
    X_1 = x[cols]
    model = sm.OLS(y, X_1).fit()
    p = pd.Series(model.pvalues.values, index=cols)
    pmax = max(p)
    feature_max_p = p.idxmax()
    if (pmax>0.05):
        cols.remove(feature_max_p)
    else:
        break
            
selected_features_BE = cols
print(selected_features_BE)
# Out:
# ['1', 'INDUS', 'CHAS', 'RM', 'AGE', 'DIS', 'RAD', 'PTRATIO', 'CRIM CHAS', 'CRIM RM', 'CRIM TAX', 'CRIM LSTAT', 'ZN NOX', 'ZN RM', 'ZN TAX', 'ZN PTRATIO', 'INDUS^2', 'INDUS RM', 'INDUS B', 'CHAS^2', 'CHAS NOX', 'CHAS RM', 'CHAS PTRATIO', 'NOX DIS', 'NOX RAD', 'NOX TAX', 'NOX PTRATIO', 'NOX LSTAT', 'RM^2', 'RM AGE', 'RM TAX', 'RM PTRATIO', 'RM LSTAT', 'AGE RAD', 'AGE TAX', 'AGE B', 'AGE LSTAT', 'DIS^2', 'DIS RAD', 'DIS TAX', 'DIS LSTAT', 'RAD^2', 'RAD TAX', 'RAD LSTAT', 'TAX^2', 'TAX PTRATIO', 'TAX B', 'PTRATIO B', 'LSTAT^2']

# %%
x = x[selected_features_BE]
model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     113.5
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):          5.20e-222
# Time:                        15:18:39   Log-Likelihood:                -1198.3
# No. Observations:                 506   AIC:                             2493.
# Df Residuals:                     458   BIC:                             2696.
# Df Model:                          47
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 1              -67.3046     22.643     -2.972      0.003    -111.802     -22.807
# INDUS           -4.3946      0.565     -7.771      0.000      -5.506      -3.283
# CHAS            30.9234      5.317      5.816      0.000      20.475      41.371
# RM              18.8618      4.385      4.302      0.000      10.245      27.479
# AGE              0.8748      0.123      7.128      0.000       0.634       1.116
# DIS            -11.5786      1.593     -7.267      0.000     -14.710      -8.447
# RAD              1.0910      0.452      2.412      0.016       0.202       1.980
# PTRATIO          3.5131      1.150      3.056      0.002       1.254       5.772
# CRIM CHAS        2.3287      0.365      6.385      0.000       1.612       3.046
# CRIM RM          0.1333      0.033      4.095      0.000       0.069       0.197
# CRIM TAX        -0.0020      0.000     -5.211      0.000      -0.003      -0.001
# CRIM LSTAT       0.0169      0.004      4.207      0.000       0.009       0.025
# ZN NOX          -0.4958      0.198     -2.505      0.013      -0.885      -0.107
# ZN RM            0.0277      0.009      3.085      0.002       0.010       0.045
# ZN TAX           0.0006      0.000      4.964      0.000       0.000       0.001
# ZN PTRATIO      -0.0088      0.004     -2.225      0.027      -0.017      -0.001
# INDUS^2          0.0393      0.007      6.043      0.000       0.027       0.052
# INDUS RM         0.3802      0.074      5.138      0.000       0.235       0.526
# INDUS B          0.0032      0.001      4.155      0.000       0.002       0.005
# CHAS^2          30.9234      5.317      5.816      0.000      20.475      41.371
# CHAS NOX       -37.9265      5.843     -6.491      0.000     -49.409     -26.444
# CHAS RM         -4.6577      0.741     -6.286      0.000      -6.114      -3.202
# CHAS PTRATIO    -0.6876      0.347     -1.982      0.048      -1.369      -0.006
# NOX DIS         16.3187      2.606      6.262      0.000      11.197      21.440
# NOX RAD         -3.0094      0.578     -5.210      0.000      -4.145      -1.874
# NOX TAX          0.2106      0.042      5.014      0.000       0.128       0.293
# NOX PTRATIO     -7.2099      1.150     -6.270      0.000      -9.470      -4.950
# NOX LSTAT        0.6877      0.320      2.146      0.032       0.058       1.317
# RM^2             0.5029      0.221      2.277      0.023       0.069       0.937
# RM AGE          -0.0745      0.014     -5.303      0.000      -0.102      -0.047
# RM TAX          -0.0202      0.003     -7.232      0.000      -0.026      -0.015
# RM PTRATIO      -0.5326      0.126     -4.234      0.000      -0.780      -0.285
# RM LSTAT        -0.1365      0.032     -4.252      0.000      -0.200      -0.073
# AGE RAD          0.0120      0.003      3.933      0.000       0.006       0.018
# AGE TAX         -0.0005      0.000     -3.358      0.001      -0.001      -0.000
# AGE B           -0.0008      0.000     -5.294      0.000      -0.001      -0.000
# AGE LSTAT       -0.0086      0.001     -5.860      0.000      -0.011      -0.006
# DIS^2            0.3500      0.053      6.553      0.000       0.245       0.455
# DIS RAD         -0.1188      0.040     -2.980      0.003      -0.197      -0.040
# DIS TAX         -0.0035      0.002     -1.994      0.047      -0.007   -5.09e-05
# DIS LSTAT        0.0984      0.022      4.407      0.000       0.055       0.142
# RAD^2           -0.1378      0.031     -4.377      0.000      -0.200      -0.076
# RAD TAX          0.0075      0.002      4.677      0.000       0.004       0.011
# RAD LSTAT       -0.0359      0.004     -8.411      0.000      -0.044      -0.028
# TAX^2        -8.636e-05   2.05e-05     -4.206      0.000      -0.000    -4.6e-05
# TAX PTRATIO      0.0057      0.001      4.909      0.000       0.003       0.008
# TAX B        -8.985e-05   2.47e-05     -3.641      0.000      -0.000   -4.14e-05
# PTRATIO B        0.0036      0.001      4.588      0.000       0.002       0.005
# LSTAT^2          0.0208      0.003      6.596      0.000       0.015       0.027
# ==============================================================================
# Omnibus:                      134.797   Durbin-Watson:                   1.523
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              816.180
# Skew:                           1.011   Prob(JB):                    5.87e-178
# Kurtosis:                       8.884   Cond. No.                     1.19e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.98e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
model = sm.OLS(y_train, X_train).fit()
#print(model.summary())
print(model.rsquared)

y_pred = model.predict(X_train)
mse = mean_squared_error(y_train, y_pred)

print('RMSE: ', np.sqrt(mse))
# Out:
# 0.933402106563878
# RMSE:  2.4194469821210616

# %%
from sklearn.metrics import r2_score, mean_squared_error
y_pred = model.predict(X_test)

r2_score(y_test, y_pred)

mse = mean_squared_error(y_test, y_pred)

print('RMSE: ', np.sqrt(mse))
# Out:
# RMSE:  3.0646305441015325
